# %%
import pandas as pd

# %%
df_principal = pd.read_excel("/content/Imersão Python - Tabela de ações - #01.xlsx",sheet_name="Principal")
df_principal.head(11)
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)  Var. Sem. (%)  Var. Mês (%)  \
# 0   USIM5 2024-01-26         9.50          5.20          11.76          2.26
# 1   CMIN3 2024-01-26         6.82          2.40           2.40        -12.11
# 2   PETR3 2024-01-26        41.96          2.19           7.73          7.64
# 3   SUZB3 2024-01-26        52.91          2.04           2.14         -4.89
# 4   CPFE3 2024-01-26        37.10          2.03           2.49         -3.66
# 5   PRIO3 2024-01-26        45.69          1.98           2.42         -0.78
# 6   PETR4 2024-01-26        39.96          1.73           6.47          7.30
# 7   VALE3 2024-01-26        69.50          1.66           2.06         -9.97
# 8   MULT3 2024-01-26        28.19          1.58           2.03         -0.81
# 9   ITUB4 2024-01-26        32.81          1.48          -0.39         -3.36
# 10  RDOR3 2024-01-26        27.56          1.43           3.41         -4.17
#
#     Var. Ano (%)  Var. 12M (%)  Val. Mín  Val. Máx    Volume  Variação (%)  \
# 0           2.26         15.97      9.18      9.56  319,16 M        0.0520
# 1         -12.11         50.56      6.66      6.86   32,65 M        0.0240
# 2           7.64         77.55     40.81     42.34  436,69 M        0.0219
# 3          -4.89         18.85     51.89     53.17  162,55 M        0.0204
# 4          -3.66         20.70     36.37     37.32   73,42 M        0.0203
# 5          -0.78          8.08     44.25     45.69  319,92 M        0.0198
# 6           7.30         95.01     38.91     40.09    1,64 B        0.0173
# 7          -9.97        -23.49     67.50     69.81    1,89 B        0.0166
# 8          -0.81         24.02     27.71     28.36  104,16 M        0.0158
# 9          -3.36         34.25     32.35     32.91   473,2 M        0.0148
# 10         -4.17         -6.01     26.90     27.91   71,62 M        0.0143
#
#     Valor Inicial(R$)  Quantidade de ações    Variação $ Resultado  \
# 0            9.030418            515117391  2.418897e+08     subiu
# 1            6.660156           1110559345  1.775160e+08     subiu
# 2           41.060769           2379877655  2.140059e+09     subiu
# 3           51.852215            683452836  7.229463e+08     subiu
# 4           36.361854            187732538  1.385740e+08     subiu
# 5           44.802903            800010734  7.096875e+08     subiu
# 6           39.280448           4566445852  3.103136e+09     subiu
# 7           68.365139           4196924316  4.762927e+09     subiu
# 8           27.751526            268505432  1.177327e+08     subiu
# 9           32.331494           4801593832  2.297592e+09     subiu
# 10          27.171448           1168230366  4.539179e+08     subiu
#
#    Nome da Empresa          Segmento  Anos       Cat_Idade
# 0         Usiminas        Siderurgia    64  entre 50 e 100
# 1    CSN Mineração         Mineração     8    menor que 50
# 2        Petrobras    Petróleo e Gás    69  entre 50 e 100
# 3           Suzano  Papel e Celulose    99  entre 50 e 100
# 4     CPFL Energia  Energia Elétrica   109   maior que 100
# 5         PetroRio    Petróleo e Gás    12    menor que 50
# 6        Petrobras    Petróleo e Gás    69  entre 50 e 100
# 7             Vale         Mineração    79  entre 50 e 100
# 8        Multiplan  Shopping Centers    48    menor que 50
# 9    Itaú Unibanco            Bancos    13    menor que 50
# 10       Rede D'Or             Saúde    46    menor que 50

# %%
df_total_de_acoes = pd.read_excel("/content/Imersão Python - Tabela de ações - #01.xlsx",sheet_name="Total_de_acoes")
df_total_de_acoes.head(11)
# Out:
#    Código  Qtde. Teórica
# 0   RRRP3   2.356656e+08
# 1   ALOS3   5.326166e+08
# 2   ALPA4   1.767340e+08
# 3   ABEV3   4.394246e+09
# 4   ARZZ3   6.230589e+07
# 5   ASAI3   1.349218e+09
# 6   AZUL4   3.275937e+08
# 7   B3SA3   5.602790e+09
# 8   BBSE3   6.717508e+08
# 9   BBDC3   1.500729e+09
# 10  BBDC4   5.146577e+09

# %%
df_tickets = pd.read_excel("/content/Imersão Python - Tabela de ações - #01.xlsx",sheet_name="Ticker")
df_tickets.head(11)
# Out:
#    Ticker            Nome
# 0   MGLU3  Magazine Luiza
# 1   HAPV3         Hapvida
# 2   PETR4       Petrobras
# 3   B3SA3              B3
# 4   USIM5        Usiminas
# 5   CVCB3             CVC
# 6   CIEL3           Cielo
# 7   VALE3            Vale
# 8   GOLL4             GOL
# 9   BBDC4  Banco Bradesco
# 10  AZUL4            Azul

# %%
df_chatgpt = pd.read_excel("/content/Imersão Python - Tabela de ações - #01.xlsx",sheet_name="Chatgpt")
df_chatgpt.head(11)
# Out:
#    Nome da Empresa          Segmento  Idade em anos
# 0         Usiminas        Siderurgia             64
# 1    CSN Mineração         Mineração              8
# 2        Petrobras    Petróleo e Gás             69
# 3           Suzano  Papel e Celulose             99
# 4     CPFL Energia  Energia Elétrica            109
# 5         PetroRio    Petróleo e Gás             12
# 6        Petrobras    Petróleo e Gás             69
# 7             Vale         Mineração             79
# 8        Multiplan  Shopping Centers             48
# 9    Itaú Unibanco            Bancos             13
# 10       Rede D'Or             Saúde             46

# %%
df_principal=df_principal[['Ativo','Data','Último (R$)','Var. Dia (%)']].copy()
df_principal
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)
# 0   USIM5 2024-01-26         9.50          5.20
# 1   CMIN3 2024-01-26         6.82          2.40
# 2   PETR3 2024-01-26        41.96          2.19
# 3   SUZB3 2024-01-26        52.91          2.04
# 4   CPFE3 2024-01-26        37.10          2.03
# ..    ...        ...          ...           ...
# 76  CRFB3 2024-01-26        10.71         -2.45
# 77  BHIA3 2024-01-26         8.70         -2.46
# 78  RENT3 2024-01-26        56.24         -3.63
# 79  CVCB3 2024-01-26         3.07         -4.36
# 80  GOLL4 2024-01-26         5.92         -8.07
#
# [81 rows x 4 columns]

# %%
df_principal=df_principal.rename(columns={'Último (R$)':'valor_final','Var. Dia (%)':'var_dias_pct'}).copy()
df_principal
# Out:
#     Ativo       Data  valor_final  var_dias_pct  Var_pct  var_pct  \
# 0   USIM5 2024-01-26         9.50          5.20   0.0520   0.0520
# 1   CMIN3 2024-01-26         6.82          2.40   0.0240   0.0240
# 2   PETR3 2024-01-26        41.96          2.19   0.0219   0.0219
# 3   SUZB3 2024-01-26        52.91          2.04   0.0204   0.0204
# 4   CPFE3 2024-01-26        37.10          2.03   0.0203   0.0203
# ..    ...        ...          ...           ...      ...      ...
# 76  CRFB3 2024-01-26        10.71         -2.45  -0.0245  -0.0245
# 77  BHIA3 2024-01-26         8.70         -2.46  -0.0246  -0.0246
# 78  RENT3 2024-01-26        56.24         -3.63  -0.0363  -0.0363
# 79  CVCB3 2024-01-26         3.07         -4.36  -0.0436  -0.0436
# 80  GOLL4 2024-01-26         5.92         -8.07  -0.0807  -0.0807
#
#     valor_inicial Código  Qtde. Teórica
# 0        9.030418  USIM5   5.151174e+08
# 1        6.660156  CMIN3   1.110559e+09
# 2       41.060769  PETR3   2.379878e+09
# 3       51.852215  SUZB3   6.834528e+08
# 4       36.361854  CPFE3   1.877325e+08
# ..            ...    ...            ...
# 76      10.978985  CRFB3   5.339906e+08
# 77       8.919418  BHIA3   9.484305e+07
# 78      58.358410  RENT3   8.532023e+08
# 79       3.209954  CVCB3   5.255828e+08
# 80       6.439682  GOLL4   1.981849e+08
#
# [81 rows x 9 columns]

# %%
df_principal['var_pct']=df_principal['var_dias_pct']/100
df_principal['valor_inicial']=df_principal['valor_final']/(df_principal['var_pct']+1)
df_principal
# Out:
#     Ativo       Data  valor_final  var_dias_pct  Var_pct  var_pct  \
# 0   USIM5 2024-01-26         9.50          5.20   0.0520   0.0520
# 1   CMIN3 2024-01-26         6.82          2.40   0.0240   0.0240
# 2   PETR3 2024-01-26        41.96          2.19   0.0219   0.0219
# 3   SUZB3 2024-01-26        52.91          2.04   0.0204   0.0204
# 4   CPFE3 2024-01-26        37.10          2.03   0.0203   0.0203
# ..    ...        ...          ...           ...      ...      ...
# 76  CRFB3 2024-01-26        10.71         -2.45  -0.0245  -0.0245
# 77  BHIA3 2024-01-26         8.70         -2.46  -0.0246  -0.0246
# 78  RENT3 2024-01-26        56.24         -3.63  -0.0363  -0.0363
# 79  CVCB3 2024-01-26         3.07         -4.36  -0.0436  -0.0436
# 80  GOLL4 2024-01-26         5.92         -8.07  -0.0807  -0.0807
#
#     valor_inicial
# 0        9.030418
# 1        6.660156
# 2       41.060769
# 3       51.852215
# 4       36.361854
# ..            ...
# 76      10.978985
# 77       8.919418
# 78      58.358410
# 79       3.209954
# 80       6.439682
#
# [81 rows x 7 columns]

# %%
df_principal=df_principal.merge(df_total_de_acoes,left_on='Ativo',right_on='Código',how='left')
df_principal
# Out:
#     Ativo       Data  valor_final  var_dias_pct  Var_pct  var_pct  \
# 0   USIM5 2024-01-26         9.50          5.20   0.0520   0.0520
# 1   CMIN3 2024-01-26         6.82          2.40   0.0240   0.0240
# 2   PETR3 2024-01-26        41.96          2.19   0.0219   0.0219
# 3   SUZB3 2024-01-26        52.91          2.04   0.0204   0.0204
# 4   CPFE3 2024-01-26        37.10          2.03   0.0203   0.0203
# ..    ...        ...          ...           ...      ...      ...
# 76  CRFB3 2024-01-26        10.71         -2.45  -0.0245  -0.0245
# 77  BHIA3 2024-01-26         8.70         -2.46  -0.0246  -0.0246
# 78  RENT3 2024-01-26        56.24         -3.63  -0.0363  -0.0363
# 79  CVCB3 2024-01-26         3.07         -4.36  -0.0436  -0.0436
# 80  GOLL4 2024-01-26         5.92         -8.07  -0.0807  -0.0807
#
#     valor_inicial Código  Qtde. Teórica
# 0        9.030418  USIM5   5.151174e+08
# 1        6.660156  CMIN3   1.110559e+09
# 2       41.060769  PETR3   2.379878e+09
# 3       51.852215  SUZB3   6.834528e+08
# 4       36.361854  CPFE3   1.877325e+08
# ..            ...    ...            ...
# 76      10.978985  CRFB3   5.339906e+08
# 77       8.919418  BHIA3   9.484305e+07
# 78      58.358410  RENT3   8.532023e+08
# 79       3.209954  CVCB3   5.255828e+08
# 80       6.439682  GOLL4   1.981849e+08
#
# [81 rows x 9 columns]

# %%
df_principal= df_principal.drop(columns=['Código','Var_pct'])
df_principal
# Out:
#     Ativo       Data  valor_final  var_dias_pct  var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50          5.20   0.0520       9.030418
# 1   CMIN3 2024-01-26         6.82          2.40   0.0240       6.660156
# 2   PETR3 2024-01-26        41.96          2.19   0.0219      41.060769
# 3   SUZB3 2024-01-26        52.91          2.04   0.0204      51.852215
# 4   CPFE3 2024-01-26        37.10          2.03   0.0203      36.361854
# ..    ...        ...          ...           ...      ...            ...
# 76  CRFB3 2024-01-26        10.71         -2.45  -0.0245      10.978985
# 77  BHIA3 2024-01-26         8.70         -2.46  -0.0246       8.919418
# 78  RENT3 2024-01-26        56.24         -3.63  -0.0363      58.358410
# 79  CVCB3 2024-01-26         3.07         -4.36  -0.0436       3.209954
# 80  GOLL4 2024-01-26         5.92         -8.07  -0.0807       6.439682
#
#     Qtde. Teórica
# 0    5.151174e+08
# 1    1.110559e+09
# 2    2.379878e+09
# 3    6.834528e+08
# 4    1.877325e+08
# ..            ...
# 76   5.339906e+08
# 77   9.484305e+07
# 78   8.532023e+08
# 79   5.255828e+08
# 80   1.981849e+08
#
# [81 rows x 7 columns]

# %%
df_principal=df_principal.rename(columns={'Qtde. Teórica':'Qtde_Teorica'}).copy()
df_principal
# Out:
#     Ativo       Data  valor_final  var_dias_pct  var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50          5.20   0.0520       9.030418
# 1   CMIN3 2024-01-26         6.82          2.40   0.0240       6.660156
# 2   PETR3 2024-01-26        41.96          2.19   0.0219      41.060769
# 3   SUZB3 2024-01-26        52.91          2.04   0.0204      51.852215
# 4   CPFE3 2024-01-26        37.10          2.03   0.0203      36.361854
# ..    ...        ...          ...           ...      ...            ...
# 76  CRFB3 2024-01-26        10.71         -2.45  -0.0245      10.978985
# 77  BHIA3 2024-01-26         8.70         -2.46  -0.0246       8.919418
# 78  RENT3 2024-01-26        56.24         -3.63  -0.0363      58.358410
# 79  CVCB3 2024-01-26         3.07         -4.36  -0.0436       3.209954
# 80  GOLL4 2024-01-26         5.92         -8.07  -0.0807       6.439682
#
#     Qtde_Teorica
# 0   5.151174e+08
# 1   1.110559e+09
# 2   2.379878e+09
# 3   6.834528e+08
# 4   1.877325e+08
# ..           ...
# 76  5.339906e+08
# 77  9.484305e+07
# 78  8.532023e+08
# 79  5.255828e+08
# 80  1.981849e+08
#
# [81 rows x 7 columns]

# %%
df_principal['variacao_rs']= (df_principal['valor_final']-df_principal['valor_inicial'])*df_principal['Qtde_Teorica']
df_principal
# Out:
#     Ativo       Data  valor_final  var_dias_pct  var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50          5.20   0.0520       9.030418
# 1   CMIN3 2024-01-26         6.82          2.40   0.0240       6.660156
# 2   PETR3 2024-01-26        41.96          2.19   0.0219      41.060769
# 3   SUZB3 2024-01-26        52.91          2.04   0.0204      51.852215
# 4   CPFE3 2024-01-26        37.10          2.03   0.0203      36.361854
# ..    ...        ...          ...           ...      ...            ...
# 76  CRFB3 2024-01-26        10.71         -2.45  -0.0245      10.978985
# 77  BHIA3 2024-01-26         8.70         -2.46  -0.0246       8.919418
# 78  RENT3 2024-01-26        56.24         -3.63  -0.0363      58.358410
# 79  CVCB3 2024-01-26         3.07         -4.36  -0.0436       3.209954
# 80  GOLL4 2024-01-26         5.92         -8.07  -0.0807       6.439682
#
#     Qtde_Teorica   variacao_rs
# 0   5.151174e+08  2.418897e+08
# 1   1.110559e+09  1.775160e+08
# 2   2.379878e+09  2.140059e+09
# 3   6.834528e+08  7.229463e+08
# 4   1.877325e+08  1.385740e+08
# ..           ...           ...
# 76  5.339906e+08 -1.436355e+08
# 77  9.484305e+07 -2.081024e+07
# 78  8.532023e+08 -1.807433e+09
# 79  5.255828e+08 -7.355741e+07
# 80  1.981849e+08 -1.029932e+08
#
# [81 rows x 8 columns]

# %%
pd.options.display.float_format = "{:.2f}".format
df_principal
# Out:
#     Ativo       Data  valor_final  var_dias_pct  var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50          5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82          2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96          2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91          2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10          2.03     0.02          36.36
# ..    ...        ...          ...           ...      ...            ...
# 76  CRFB3 2024-01-26        10.71         -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70         -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24         -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07         -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92         -8.07    -0.08           6.44
#
#     Qtde_Teorica    variacao_rs
# 0   515117391.00   241889725.43
# 1  1110559345.00   177515970.30
# 2  2379877655.00  2140059393.53
# 3   683452836.00   722946282.71
# 4   187732538.00   138573955.06
# ..           ...            ...
# 76  533990587.00  -143635530.57
# 77   94843047.00   -20810240.84
# 78  853202347.00 -1807432634.46
# 79  525582771.00   -73557408.06
# 80  198184909.00  -102993202.62
#
# [81 rows x 8 columns]

# %%
df_principal['Qtde_Teorica'] = df_principal['Qtde_Teorica'].astype(int)
df_principal
# Out:
#     Ativo       Data  valor_final  var_dias_pct  var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50          5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82          2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96          2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91          2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10          2.03     0.02          36.36
# ..    ...        ...          ...           ...      ...            ...
# 76  CRFB3 2024-01-26        10.71         -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70         -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24         -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07         -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92         -8.07    -0.08           6.44
#
#     Qtde_Teorica    variacao_rs
# 0      515117391   241889725.43
# 1     1110559345   177515970.30
# 2     2379877655  2140059393.53
# 3      683452836   722946282.71
# 4      187732538   138573955.06
# ..           ...            ...
# 76     533990587  -143635530.57
# 77      94843047   -20810240.84
# 78     853202347 -1807432634.46
# 79     525582771   -73557408.06
# 80     198184909  -102993202.62
#
# [81 rows x 8 columns]

# %%
df_principal['resultado']  = df_principal['variacao_rs'].apply(lambda x: 'subiu' if x > 0 else ('desceu' if x < 0 else 'estavel'))

# %%
df_principal
# Out:
#     Ativo       Data  valor_final  var_dias_pct  var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50          5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82          2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96          2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91          2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10          2.03     0.02          36.36
# ..    ...        ...          ...           ...      ...            ...
# 76  CRFB3 2024-01-26        10.71         -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70         -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24         -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07         -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92         -8.07    -0.08           6.44
#
#     Qtde_Teorica    variacao_rs resultado
# 0      515117391   241889725.43     subiu
# 1     1110559345   177515970.30     subiu
# 2     2379877655  2140059393.53     subiu
# 3      683452836   722946282.71     subiu
# 4      187732538   138573955.06     subiu
# ..           ...            ...       ...
# 76     533990587  -143635530.57    desceu
# 77      94843047   -20810240.84    desceu
# 78     853202347 -1807432634.46    desceu
# 79     525582771   -73557408.06    desceu
# 80     198184909  -102993202.62    desceu
#
# [81 rows x 9 columns]

# %%
df_principal = df_principal.merge(df_tickets,left_on='Ativo',right_on='Ticker',how='left')
df_principal
# Out:
#     Ativo       Data  valor_final  var_dias_pct  var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50          5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82          2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96          2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91          2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10          2.03     0.02          36.36
# ..    ...        ...          ...           ...      ...            ...
# 76  CRFB3 2024-01-26        10.71         -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70         -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24         -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07         -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92         -8.07    -0.08           6.44
#
#     Qtde_Teorica    variacao_rs resultado Ticker              Nome
# 0      515117391   241889725.43     subiu  USIM5          Usiminas
# 1     1110559345   177515970.30     subiu  CMIN3     CSN Mineração
# 2     2379877655  2140059393.53     subiu  PETR3         Petrobras
# 3      683452836   722946282.71     subiu  SUZB3            Suzano
# 4      187732538   138573955.06     subiu  CPFE3      CPFL Energia
# ..           ...            ...       ...    ...               ...
# 76     533990587  -143635530.57    desceu  CRFB3  Carrefour Brasil
# 77      94843047   -20810240.84    desceu  BHIA3       Casas Bahia
# 78     853202347 -1807432634.46    desceu  RENT3          Localiza
# 79     525582771   -73557408.06    desceu  CVCB3               CVC
# 80     198184909  -102993202.62    desceu  GOLL4               GOL
#
# [81 rows x 11 columns]

# %%
df_principal= df_principal.drop(columns=['Ticker'])
df_principal
# Out:
#     Ativo       Data  valor_final  var_dias_pct  var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50          5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82          2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96          2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91          2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10          2.03     0.02          36.36
# ..    ...        ...          ...           ...      ...            ...
# 76  CRFB3 2024-01-26        10.71         -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70         -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24         -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07         -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92         -8.07    -0.08           6.44
#
#     Qtde_Teorica    variacao_rs resultado              Nome
# 0      515117391   241889725.43     subiu          Usiminas
# 1     1110559345   177515970.30     subiu     CSN Mineração
# 2     2379877655  2140059393.53     subiu         Petrobras
# 3      683452836   722946282.71     subiu            Suzano
# 4      187732538   138573955.06     subiu      CPFL Energia
# ..           ...            ...       ...               ...
# 76     533990587  -143635530.57    desceu  Carrefour Brasil
# 77      94843047   -20810240.84    desceu       Casas Bahia
# 78     853202347 -1807432634.46    desceu          Localiza
# 79     525582771   -73557408.06    desceu               CVC
# 80     198184909  -102993202.62    desceu               GOL
#
# [81 rows x 10 columns]

# %%
df_principal = df_principal.merge(df_chatgpt,left_on='Nome',right_on='Nome da Empresa',how='left')
df_principal
# Out:
#     Ativo       Data  valor_final  var_dias_pct  var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50          5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82          2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96          2.19     0.02          41.06
# 3   PETR3 2024-01-26        41.96          2.19     0.02          41.06
# 4   SUZB3 2024-01-26        52.91          2.04     0.02          51.85
# ..    ...        ...          ...           ...      ...            ...
# 78  CRFB3 2024-01-26        10.71         -2.45    -0.02          10.98
# 79  BHIA3 2024-01-26         8.70         -2.46    -0.02           8.92
# 80  RENT3 2024-01-26        56.24         -3.63    -0.04          58.36
# 81  CVCB3 2024-01-26         3.07         -4.36    -0.04           3.21
# 82  GOLL4 2024-01-26         5.92         -8.07    -0.08           6.44
#
#     Qtde_Teorica    variacao_rs resultado              Nome   Nome da Empresa  \
# 0      515117391   241889725.43     subiu          Usiminas          Usiminas
# 1     1110559345   177515970.30     subiu     CSN Mineração     CSN Mineração
# 2     2379877655  2140059393.53     subiu         Petrobras         Petrobras
# 3     2379877655  2140059393.53     subiu         Petrobras         Petrobras
# 4      683452836   722946282.71     subiu            Suzano            Suzano
# ..           ...            ...       ...               ...               ...
# 78     533990587  -143635530.57    desceu  Carrefour Brasil  Carrefour Brasil
# 79      94843047   -20810240.84    desceu       Casas Bahia       Casas Bahia
# 80     853202347 -1807432634.46    desceu          Localiza          Localiza
# 81     525582771   -73557408.06    desceu               CVC               CVC
# 82     198184909  -102993202.62    desceu               GOL               GOL
#
#              Segmento  Idade em anos
# 0          Siderurgia             64
# 1           Mineração              8
# 2      Petróleo e Gás             69
# 3      Petróleo e Gás             69
# 4    Papel e Celulose             99
# ..                ...            ...
# 78             Varejo             47
# 79             Varejo             63
# 80  Aluguel de Carros             48
# 81            Turismo             49
# 82   Transporte Aéreo             21
#
# [83 rows x 13 columns]

# %%
df_principal=df_principal.rename(columns={'Nome da Empresa':'nome_empresa','Idade em anos':'idade_anos'}).copy()
df_principal
# Out:
#     Ativo       Data  valor_final  var_dias_pct  var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50          5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82          2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96          2.19     0.02          41.06
# 3   PETR3 2024-01-26        41.96          2.19     0.02          41.06
# 4   SUZB3 2024-01-26        52.91          2.04     0.02          51.85
# ..    ...        ...          ...           ...      ...            ...
# 78  CRFB3 2024-01-26        10.71         -2.45    -0.02          10.98
# 79  BHIA3 2024-01-26         8.70         -2.46    -0.02           8.92
# 80  RENT3 2024-01-26        56.24         -3.63    -0.04          58.36
# 81  CVCB3 2024-01-26         3.07         -4.36    -0.04           3.21
# 82  GOLL4 2024-01-26         5.92         -8.07    -0.08           6.44
#
#     Qtde_Teorica    variacao_rs resultado              Nome      nome_empresa  \
# 0      515117391   241889725.43     subiu          Usiminas          Usiminas
# 1     1110559345   177515970.30     subiu     CSN Mineração     CSN Mineração
# 2     2379877655  2140059393.53     subiu         Petrobras         Petrobras
# 3     2379877655  2140059393.53     subiu         Petrobras         Petrobras
# 4      683452836   722946282.71     subiu            Suzano            Suzano
# ..           ...            ...       ...               ...               ...
# 78     533990587  -143635530.57    desceu  Carrefour Brasil  Carrefour Brasil
# 79      94843047   -20810240.84    desceu       Casas Bahia       Casas Bahia
# 80     853202347 -1807432634.46    desceu          Localiza          Localiza
# 81     525582771   -73557408.06    desceu               CVC               CVC
# 82     198184909  -102993202.62    desceu               GOL               GOL
#
#              Segmento  idade_anos
# 0          Siderurgia          64
# 1           Mineração           8
# 2      Petróleo e Gás          69
# 3      Petróleo e Gás          69
# 4    Papel e Celulose          99
# ..                ...         ...
# 78             Varejo          47
# 79             Varejo          63
# 80  Aluguel de Carros          48
# 81            Turismo          49
# 82   Transporte Aéreo          21
#
# [83 rows x 13 columns]

# %%
df_principal= df_principal.drop(columns=['Nome'])
df_principal
# Out:
#     Ativo       Data  valor_final  var_dias_pct  var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50          5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82          2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96          2.19     0.02          41.06
# 3   PETR3 2024-01-26        41.96          2.19     0.02          41.06
# 4   SUZB3 2024-01-26        52.91          2.04     0.02          51.85
# ..    ...        ...          ...           ...      ...            ...
# 78  CRFB3 2024-01-26        10.71         -2.45    -0.02          10.98
# 79  BHIA3 2024-01-26         8.70         -2.46    -0.02           8.92
# 80  RENT3 2024-01-26        56.24         -3.63    -0.04          58.36
# 81  CVCB3 2024-01-26         3.07         -4.36    -0.04           3.21
# 82  GOLL4 2024-01-26         5.92         -8.07    -0.08           6.44
#
#     Qtde_Teorica    variacao_rs resultado      nome_empresa  \
# 0      515117391   241889725.43     subiu          Usiminas
# 1     1110559345   177515970.30     subiu     CSN Mineração
# 2     2379877655  2140059393.53     subiu         Petrobras
# 3     2379877655  2140059393.53     subiu         Petrobras
# 4      683452836   722946282.71     subiu            Suzano
# ..           ...            ...       ...               ...
# 78     533990587  -143635530.57    desceu  Carrefour Brasil
# 79      94843047   -20810240.84    desceu       Casas Bahia
# 80     853202347 -1807432634.46    desceu          Localiza
# 81     525582771   -73557408.06    desceu               CVC
# 82     198184909  -102993202.62    desceu               GOL
#
#              Segmento  idade_anos
# 0          Siderurgia          64
# 1           Mineração           8
# 2      Petróleo e Gás          69
# 3      Petróleo e Gás          69
# 4    Papel e Celulose          99
# ..                ...         ...
# 78             Varejo          47
# 79             Varejo          63
# 80  Aluguel de Carros          48
# 81            Turismo          49
# 82   Transporte Aéreo          21
#
# [83 rows x 12 columns]

# %%
df_principal['categ_idade'] = np.where(df_principal['idade_anos'] > 100, 'maior que 100', np.where(df_principal['idade_anos'] < 50, 'menor que 50', 'entre 50 e 100'))
df_principal
# Out:
#     Ativo       Data  valor_final  var_dias_pct  var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50          5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82          2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96          2.19     0.02          41.06
# 3   PETR3 2024-01-26        41.96          2.19     0.02          41.06
# 4   SUZB3 2024-01-26        52.91          2.04     0.02          51.85
# ..    ...        ...          ...           ...      ...            ...
# 78  CRFB3 2024-01-26        10.71         -2.45    -0.02          10.98
# 79  BHIA3 2024-01-26         8.70         -2.46    -0.02           8.92
# 80  RENT3 2024-01-26        56.24         -3.63    -0.04          58.36
# 81  CVCB3 2024-01-26         3.07         -4.36    -0.04           3.21
# 82  GOLL4 2024-01-26         5.92         -8.07    -0.08           6.44
#
#     Qtde_Teorica    variacao_rs resultado      nome_empresa  \
# 0      515117391   241889725.00     subiu          Usiminas
# 1     1110559345   177515970.00     subiu     CSN Mineração
# 2     2379877655  2140059393.00     subiu         Petrobras
# 3     2379877655  2140059393.00     subiu         Petrobras
# 4      683452836   722946282.00     subiu            Suzano
# ..           ...            ...       ...               ...
# 78     533990587  -143635530.00    desceu  Carrefour Brasil
# 79      94843047   -20810240.00    desceu       Casas Bahia
# 80     853202347 -1807432634.00    desceu          Localiza
# 81     525582771   -73557408.00    desceu               CVC
# 82     198184909  -102993202.00    desceu               GOL
#
#              Segmento  idade_anos     categ_idade
# 0          Siderurgia          64  entre 50 e 100
# 1           Mineração           8    menor que 50
# 2      Petróleo e Gás          69  entre 50 e 100
# 3      Petróleo e Gás          69  entre 50 e 100
# 4    Papel e Celulose          99  entre 50 e 100
# ..                ...         ...             ...
# 78             Varejo          47    menor que 50
# 79             Varejo          63  entre 50 e 100
# 80  Aluguel de Carros          48    menor que 50
# 81            Turismo          49    menor que 50
# 82   Transporte Aéreo          21    menor que 50
#
# [83 rows x 13 columns]

# %%
# Calculando o maior valor
maior = df_principal['variacao_rs'].max()

# Calculando o menor valor
menor = df_principal['variacao_rs'].min()

# Calculando a média
media = df_principal['variacao_rs'].mean()

# Calculando a média de quem subiu
media_subiu = df_principal[df_principal['resultado'] == 'subiu']['variacao_rs'].mean()

# Calculando a média de quem desceu
media_desceu = df_principal[df_principal['resultado'] == 'desceu']['variacao_rs'].mean()

# Imprimindo os resultados
print(type(maior))
#print(f"Maior: {float(maior):,.2f}")
#print(f"Menor: {float(menor):,.2f}")
#print(f"Média: {float(media):,.2f}")
#print(f"Média de quem subiu: {float(media_subiu):,.2f}")
#print(f"Média de quem desceu: {float(media_desceu):,.2f}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-152-f143ceb15f15> in <cell line: 17>()
#      15
#      16 # Imprimindo os resultados
# ---> 17 print(type(maior))
#      18 #print(f"Maior: {float(maior):,.2f}")
#      19 #print(f"Menor: {float(menor):,.2f}")
#
# TypeError: 'numpy.float64' object is not callable
